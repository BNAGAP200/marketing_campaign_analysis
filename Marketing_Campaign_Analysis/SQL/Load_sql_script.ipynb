# %%
sql_load = """
LOAD DATA LOCAL INFILE '../data/cleaned_marketing_data.csv'
INTO TABLE marketing_customers
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\\n'
IGNORE 1 ROWS;
"""

with open("../sql/load_data.sql", "w") as file:
    file.write(sql_load)

print("load_data.sql created.")
# Out:
# load_data.sql created.

# %%
# Out:
# Day 2 completed.
# Files created in outputs/day2:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 print("Day 2 completed.")
#       2
#       3 print("Files created in outputs/day2:")
# ----> 4 print(os.listdir("../outputs/day2"))
#       5
#       6 print("Files created in sql:")
#       7 print(os.listdir("../sql"))
#
# NameError: name 'os' is not defined
